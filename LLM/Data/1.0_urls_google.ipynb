# %%
import os
from googleapiclient.discovery import build
from dotenv import load_dotenv
import pickle
import random
import collections
from tqdm import tqdm

random.seed(333)

# %%
load_dotenv()

api_key = os.environ['GOOGLE_API']
cse_id = os.environ['GOOGLE_CSE']

# %%
# create a search query
def google_search(search_term, api_key, cse_id, **kwargs):
    
    """
    Creates a search link for the custom Google search.
    """
    
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res['items']

# %%
# search_results = google_search(palm_species[0], api_key=api_key, cse_id=cse_id)

# %%
queries = [
    "",
    "description",
    "diagnosis",
    "attributes"
]

# %% [markdown]
# ## PALMS

# %%
folder = "../../../data/OpenAI/Species/"

palm_species = pickle.load(open(F"{folder}palm_species.pkl", 'rb'))
# palm_species_random = random.sample(palm_species, 50)


try:
    folder = "../../../data/OpenAI/Urls/"
    palm_species_google = pickle.load(open(F"{folder}google_urls_palms.pkl", 'rb'))
    palm_species_urls = pickle.load(open(F"{folder}urls_palms.pkl", 'rb'))
    palms_done = list(palm_species_urls.keys())
except:
    palm_species_urls = collections.defaultdict(list)
    palm_species_google = collections.defaultdict(list)
    palms_done = []

# %%
palms_done
# Out:
# ['Actinokentia divaricata',
#  'Aiphanes minima',
#  'Archontophoenix alexandrae',
#  'Archontophoenix maxima',
#  'Archontophoenix myolensis',
#  'Archontophoenix purpurea',
#  'Archontophoenix tuckeri',
#  'Areca catechu',
#  'Areca laosensis',
#  'Arenga australasica',
#  'Astrocaryum acaule',
#  'Astrocaryum aculeatum',
#  'Astrocaryum chambira',
#  'Astrocaryum huaimi',
#  'Astrocaryum jauari',
#  'Astrocaryum javarense',
#  'Astrocaryum murumuru',
#  'Astrocaryum paramaca',
#  'Astrocaryum sciophilum',
#  'Astrocaryum sociale',
#  'Astrocaryum standleyanum',
#  'Astrocaryum vulgare',
#  'Attalea butyracea',
#  'Attalea cohune',
#  'Attalea dahlgreniana',
#  'Attalea geraensis',
#  'Attalea maripa',
#  'Attalea oleifera',
#  'Attalea phalerata',
#  'Attalea septuagenata',
#  'Attalea speciosa',
#  'Attalea tessmannii',
#  'Attalea vitrivir',
#  'Bactris dianeura',
#  'Bactris gastoniana',
#  'Bactris gracilior',
#  'Bactris grayumii',
#  'Bactris hirta',
#  'Bactris horridispatha',
#  'Bactris kunorum',
#  'Bactris longiseta',
#  'Bactris macroacantha',
#  'Bactris major',
#  'Bactris oligocarpa',
#  'Bactris pilosa',
#  'Bactris ptariana',
#  'Bactris setosa',
#  'Bactris setulosa',
#  'Bactris turbinocarpa',
#  'Balaka seemannii',
#  'Balaka streptostachys',
#  'Basselinia pancheri',
#  'Basselinia tomentosa',
#  'Bismarckia nobilis',
#  'Borassus heineanus',
#  'Brahea sarukhanii',
#  'Brassiophoenix schumannii',
#  'Butia archeri',
#  'Butia capitata',
#  'Butia paraguayensis',
#  'Butia yatay',
#  'Calyptrogyne anomala',
#  'Calyptrogyne ghiesbreghtiana',
#  'Calyptronoma occidentalis',
#  'Calyptronoma rivalis',
#  'Chamaedorea allenii',
#  'Chamaedorea angustisecta',
#  'Chamaedorea costaricana',
#  'Chamaedorea dammeriana',
#  'Chamaedorea deckeriana',
#  'Chamaedorea deneversiana',
#  'Chamaedorea elegans',
#  'Chamaedorea ernesti-augusti',
#  'Chamaedorea klotzschiana',
#  'Chamaedorea lucidifrons',
#  'Chamaedorea macrospadix',
#  'Chamaedorea metallica',
#  'Chamaedorea oblongata',
#  'Chamaedorea oreophila',
#  'Chamaedorea pauciflora',
#  'Chamaedorea pinnatifrons',
#  'Chamaedorea pochutlensis',
#  'Chamaedorea pumila',
#  'Chamaedorea pygmaea',
#  'Chamaedorea rojasiana',
#  'Chamaedorea sartorii',
#  'Chamaedorea simplex',
#  'Chamaedorea tepejilote',
#  'Chamaedorea tuerckheimii',
#  'Chamaedorea warscewiczii',
#  'Cocos nucifera',
#  'Cryosophila stauracantha',
#  'Cryosophila warscewiczii',
#  'Cyphokentia cerifera',
#  'Cyphophoenix elegans',
#  'Cyrtostachys elegans',
#  'Cyrtostachys glauca',
#  'Cyrtostachys loriae',
#  'Cyrtostachys renda',
#  'Daemonorops scapigera',
#  'Desmoncus giganteus',
#  'Desmoncus mitis',
#  'Desmoncus orthacanthos',
#  'Desmoncus polyacanthos',
#  'Desmoncus stans',
#  'Dictyocaryum fuscum',
#  'Dictyocaryum ptarianum',
#  'Dransfieldia micrantha',
#  'Drymophloeus litigiosus',
#  'Drymophloeus oliviformis',
#  'Dypsis acuminum',
#  'Dypsis ambilaensis',
#  'Dypsis andapae',
#  'Dypsis andrianatonga',
#  'Dypsis antanambensis',
#  'Dypsis arenarum',
#  'Dypsis baronii',
#  'Dypsis bejofo',
#  'Dypsis cabadae',
#  'Dypsis catatiana',
#  'Dypsis caudata',
#  'Dypsis concinna',
#  'Dypsis confusa',
#  'Dypsis coriacea',
#  'Dypsis corniculata',
#  'Dypsis coursii',
#  'Dypsis decaryi',
#  'Dypsis decipiens',
#  'Dypsis digitata',
#  'Dypsis dransfieldii',
#  'Dypsis glabrescens',
#  'Dypsis heteromorpha',
#  'Dypsis heterophylla',
#  'Dypsis hiarakae',
#  'Dypsis jumelleana',
#  'Dypsis lastelliana',
#  'Dypsis linearis',
#  'Dypsis lutescens',
#  'Dypsis malcomberi',
#  'Dypsis mananjarensis',
#  'Dypsis marojejyi',
#  'Dypsis mcdonaldiana',
#  'Dypsis minuta',
#  'Dypsis nodifera',
#  'Dypsis ovobontsira',
#  'Dypsis perrieri',
#  'Dypsis pilulifera',
#  'Dypsis prestoniana',
#  'Dypsis procumbens',
#  'Dypsis pusilla',
#  'Dypsis schatzii',
#  'Dypsis scottiana',
#  'Dypsis serpentina',
#  'Dypsis tenuissima',
#  'Dypsis thiryana',
#  'Dypsis tokoravina',
#  'Dypsis utilis',
#  'Elaeis oleifera',
#  'Euterpe catinga',
#  'Euterpe oleracea',
#  'Gaussia maya',
#  'Geonoma aspidiifolia',
#  'Geonoma baculifera',
#  'Geonoma brenesii',
#  'Geonoma camana',
#  'Geonoma chococola',
#  'Geonoma concinna',
#  'Geonoma congesta',
#  'Geonoma cuneata',
#  'Geonoma deversa',
#  'Geonoma epetiolata',
#  'Geonoma ferruginea',
#  'Geonoma hugonis',
#  'Geonoma interrupta',
#  'Geonoma laxiflora',
#  'Geonoma leptospadix',
#  'Geonoma longipedunculata',
#  'Geonoma longivaginata',
#  'Geonoma macrostachys',
#  'Geonoma maxima',
#  'Hydriastele costata',
#  'Hydriastele cylindrocarpa',
#  'Hydriastele flabellata',
#  'Hydriastele hombronii',
#  'Hydriastele longispatha',
#  'Hydriastele pinangoides',
#  'Hydriastele variabilis',
#  'Hydriastele wendlandiana',
#  'Hyophorbe indica',
#  'Hyospathe macrorhachis',
#  'Hyphaene compressa',
#  'Hyphaene coriacea',
#  'Iriartea deltoidea',
#  'Iriartella setigera',
#  'Iriartella stenocarpa',
#  'Itaya amicorum',
#  'Kentiopsis oliviformis',
#  'Kentiopsis piersoniorum',
#  'Kerriodoxa elegans',
#  'Leopoldinia piassaba',
#  'Leopoldinia pulchra',
#  'Lepidocaryum tenue',
#  'Licuala paludosa',
#  'Linospadix microcaryus',
#  'Linospadix minor',
#  'Linospadix monostachyos',
#  'Linospadix palmerianus',
#  'Livistona alfredii',
#  'Livistona benthamii',
#  'Livistona drudei',
#  'Livistona eastonii',
#  'Livistona humilis',
#  'Livistona lorophylla',
#  'Livistona saribus',
#  'Lytocaryum hoehnei',
#  'Lytocaryum weddellianum',
#  'Manicaria saccifera',
#  'Marojejya insignis',
#  'Masoala kona',
#  'Masoala madagascariensis',
#  'Mauritiella armata',
#  'Mauritiella macroclada',
#  'Maxburretia furtadoana',
#  'Normanbya normanbyi',
#  'Nypa fruticans',
#  'Oenocarpus bacaba',
#  'Oenocarpus balickii',
#  'Oenocarpus bataua',
#  'Oenocarpus distichus',
#  'Oenocarpus makeru',
#  'Oenocarpus mapora',
#  'Oenocarpus minor',
#  'Oenocarpus simplex',
#  'Oncosperma horridum',
#  'Orania disticha',
#  'Orania lauterbachiana',
#  'Orania longisquama',
#  'Orania palindan',
#  'Orania ravaka',
#  'Orania trispatha',
#  'Parajubaea cocoides',
#  'Parajubaea torallyi']

# %%
for palm in tqdm(palm_species):

    if palm in palms_done:
        print(palm, "done")
        continue

    for query in queries:
        search_query = F"{palm} {query}"

        # print(search_query)

        # Search results (10 per search)
        search_results = google_search(search_query, api_key=api_key, cse_id=cse_id)
        # Google Urls
        palm_species_google[palm] = search_results
        # Just the links
        for result in search_results:
            palm_species_urls[palm].append(result['link'])


folder = "../../../data/OpenAI/Urls/"

with open(F"{folder}urls_palms.pkl", 'wb') as f:
    pickle.dump(palm_species_urls, f)

with open(F"{folder}google_urls_palms.pkl", 'wb') as f:
    pickle.dump(palm_species_google, f)
# Out:
#   0%|          | 0/333 [00:00<?, ?it/s]
# Actinokentia divaricata done
# Aiphanes minima done
# Archontophoenix alexandrae done
# Archontophoenix maxima done
# Archontophoenix myolensis done
# Archontophoenix purpurea done
# Archontophoenix tuckeri done
# Areca catechu done
# Areca laosensis done
# Arenga australasica done
# Astrocaryum acaule done
# Astrocaryum aculeatum done
# Astrocaryum chambira done
# Astrocaryum huaimi done
# Astrocaryum jauari done
# Astrocaryum javarense done
# Astrocaryum murumuru done
# Astrocaryum paramaca done
# Astrocaryum sciophilum done
# Astrocaryum sociale done
# Astrocaryum standleyanum done
# Astrocaryum vulgare done
# Attalea butyracea done
# Attalea cohune done
# Attalea dahlgreniana done
# Attalea geraensis done
# Attalea maripa done
# Attalea oleifera done
# Attalea phalerata done
# Attalea septuagenata done
# Attalea speciosa done
# Attalea tessmannii done
# Attalea vitrivir done
# Bactris dianeura done
# Bactris gastoniana done
# Bactris gracilior done
# Bactris grayumii done
# Bactris hirta done
# Bactris horridispatha done
# Bactris kunorum done
# Bactris longiseta done
# Bactris macroacantha done
# Bactris major done
# Bactris oligocarpa done
# Bactris pilosa done
# Bactris ptariana done
# Bactris setosa done
# Bactris setulosa done
# Bactris turbinocarpa done
# Balaka seemannii done
# Balaka streptostachys done
# Basselinia pancheri done
# Basselinia tomentosa done
# Bismarckia nobilis done
# Borassus heineanus done
# Brahea sarukhanii done
# Brassiophoenix schumannii done
# Butia archeri done
# Butia capitata done
# Butia paraguayensis done
# Butia yatay done
# Calyptrogyne anomala done
# Calyptrogyne ghiesbreghtiana done
# Calyptronoma occidentalis done
# Calyptronoma rivalis done
# Chamaedorea allenii done
# Chamaedorea angustisecta done
# Chamaedorea costaricana done
# Chamaedorea dammeriana done
# Chamaedorea deckeriana done
# Chamaedorea deneversiana done
# Chamaedorea elegans done
# Chamaedorea ernesti-augusti done
# Chamaedorea klotzschiana done
# Chamaedorea lucidifrons done
# Chamaedorea macrospadix done
# Chamaedorea metallica done
# Chamaedorea oblongata done
# Chamaedorea oreophila done
# Chamaedorea pauciflora done
# Chamaedorea pinnatifrons done
# Chamaedorea pochutlensis done
# Chamaedorea pumila done
# Chamaedorea pygmaea done
# Chamaedorea rojasiana done
# Chamaedorea sartorii done
# Chamaedorea simplex done
# Chamaedorea tepejilote done
# Chamaedorea tuerckheimii done
# Chamaedorea warscewiczii done
# Cocos nucifera done
# Cryosophila stauracantha done
# Cryosophila warscewiczii done
# Cyphokentia cerifera done
# Cyphophoenix elegans done
# Cyrtostachys elegans done
# Cyrtostachys glauca done
# Cyrtostachys loriae done
# Cyrtostachys renda done
# Daemonorops scapigera done
# Desmoncus giganteus done
# Desmoncus mitis done
# Desmoncus orthacanthos done
# Desmoncus polyacanthos done
# Desmoncus stans done
# Dictyocaryum fuscum done
# Dictyocaryum ptarianum done
# Dransfieldia micrantha done
# Drymophloeus litigiosus done
# Drymophloeus oliviformis done
# Dypsis acuminum done
# Dypsis ambilaensis done
# Dypsis andapae done
# Dypsis andrianatonga done
# Dypsis antanambensis done
# Dypsis arenarum done
# Dypsis baronii done
# Dypsis bejofo done
# Dypsis cabadae done
# Dypsis catatiana done
# Dypsis caudata done
# Dypsis concinna done
# Dypsis confusa done
# Dypsis coriacea done
# Dypsis corniculata done
# Dypsis coursii done
# Dypsis decaryi done
# Dypsis decipiens done
# Dypsis digitata done
# Dypsis dransfieldii done
# Dypsis glabrescens done
# Dypsis heteromorpha done
# Dypsis heterophylla done
# Dypsis hiarakae done
# Dypsis jumelleana done
# Dypsis lastelliana done
# Dypsis linearis done
# Dypsis lutescens done
# Dypsis malcomberi done
# Dypsis mananjarensis done
# Dypsis marojejyi done
# Dypsis mcdonaldiana done
# Dypsis minuta done
# Dypsis nodifera done
# Dypsis ovobontsira done
# Dypsis perrieri done
# Dypsis pilulifera done
# Dypsis prestoniana done
# Dypsis procumbens done
# Dypsis pusilla done
# Dypsis schatzii done
# Dypsis scottiana done
# Dypsis serpentina done
# Dypsis tenuissima done
# Dypsis thiryana done
# Dypsis tokoravina done
# Dypsis utilis done
# Elaeis oleifera done
# Euterpe catinga done
# Euterpe oleracea done
# Gaussia maya done
# Geonoma aspidiifolia done
# Geonoma baculifera done
# Geonoma brenesii done
# Geonoma camana done
# Geonoma chococola done
# Geonoma concinna done
# Geonoma congesta done
# Geonoma cuneata done
# Geonoma deversa done
# Geonoma epetiolata done
# Geonoma ferruginea done
# Geonoma hugonis done
# Geonoma interrupta done
# Geonoma laxiflora done
# Geonoma leptospadix done
# Geonoma longipedunculata done
# Geonoma longivaginata done
# Geonoma macrostachys done
# Geonoma maxima done
# Hydriastele costata done
# Hydriastele cylindrocarpa done
# Hydriastele flabellata done
# Hydriastele hombronii done
# Hydriastele longispatha done
# Hydriastele pinangoides done
# Hydriastele variabilis done
# Hydriastele wendlandiana done
# Hyophorbe indica done
# Hyospathe macrorhachis done
# Hyphaene compressa done
# Hyphaene coriacea done
# Iriartea deltoidea done
# Iriartella setigera done
# Iriartella stenocarpa done
# Itaya amicorum done
# Kentiopsis oliviformis done
# Kentiopsis piersoniorum done
# Kerriodoxa elegans done
# Leopoldinia piassaba done
# Leopoldinia pulchra done
# Lepidocaryum tenue done
# Licuala paludosa done
# Linospadix microcaryus done
# Linospadix minor done
# Linospadix monostachyos done
# Linospadix palmerianus done
# Livistona alfredii done
# Livistona benthamii done
# Livistona drudei done
# Livistona eastonii done
# Livistona humilis done
# Livistona lorophylla done
# Livistona saribus done
# Lytocaryum hoehnei done
# Lytocaryum weddellianum done
# Manicaria saccifera done
# Marojejya insignis done
# Masoala kona done
# Masoala madagascariensis done
# Mauritiella armata done
# Mauritiella macroclada done
# Maxburretia furtadoana done
# Normanbya normanbyi done
# Nypa fruticans done
# Oenocarpus bacaba done
# Oenocarpus balickii done
# Oenocarpus bataua done
# Oenocarpus distichus done
# Oenocarpus makeru done
# Oenocarpus mapora done
# Oenocarpus minor done
# Oenocarpus simplex done
# Oncosperma horridum done
# Orania disticha done
# Orania lauterbachiana done
# Orania longisquama done
# Orania palindan done
# Orania ravaka done
# Orania trispatha done
# Parajubaea cocoides done
# Parajubaea torallyi done
#  80%|████████  | 268/333 [00:38<00:09,  6.96it/s]
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[7], line 13
#       8 search_query = F"{palm} {query}"
#      10 # print(search_query)
#      11
#      12 # Search results (10 per search)
# ---> 13 search_results = google_search(search_query, api_key=api_key, cse_id=cse_id)
#      14 # Google Urls
#      15 palm_species_google[palm] = search_results
#
# Cell In[3], line 9, in google_search(search_term, api_key, cse_id, **kwargs)
#       4 """
#       5 Creates a search link for the custom Google search.
#       6 """
#       8 service = build("customsearch", "v1", developerKey=api_key)
# ----> 9 res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
#      10 return res['items']
#
# File ~/Documents/Wageningen University/Period 0 - GRS 70424 Internship/venv/lib/python3.9/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/Documents/Wageningen University/Period 0 - GRS 70424 Internship/venv/lib/python3.9/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Ravenea+hildebrandtii+diagnosis&cx=13a87041f5a6df559&key=AIzaSyAiKMet5uvNWBKxmPC3OurJRs2amYdJaFA&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:830720044910'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:830720044910'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">

# %%
folder = "../../../data/OpenAI/Urls/"

with open(F"{folder}urls_palms.pkl", 'wb') as f:
    pickle.dump(palm_species_urls, f)

with open(F"{folder}google_urls_palms.pkl", 'wb') as f:
    pickle.dump(palm_species_google, f)

# %% [markdown]
# ## CARIBBEAN

# %%
folder = "../../../data/OpenAI/Species/"

caribbean_species = pickle.load(open(F"{folder}caribbean_species.pkl", 'rb'))

try:
    folder = "../../../data/OpenAI/Urls/"
    caribbean_species_google = pickle.load(open(F"{folder}google_urls_caribbean.pkl", 'rb'))
    caribbean_species_urls = pickle.load(open(F"{folder}urls_caribbean.pkl", 'rb'))
    caribbean_done = list(caribbean_species_urls.keys())
except:
    caribbean_species_urls = collections.defaultdict(list)
    caribbean_species_google = collections.defaultdict(list)
    caribbean_done = []

# %%
caribbean_done

# %%
for caribbean in tqdm(caribbean_species):

    if caribbean in caribbean_done:
        print(caribbean, "done")
        continue

    for query in queries:
        search_query = F"{caribbean} {query}"

        # print(search_query)

        # Search results (10 per search)
        search_results = google_search(search_query, api_key=api_key, cse_id=cse_id)
        # Google Urls
        caribbean_species_google[caribbean] = search_results
        # Just the links
        for result in search_results:
            caribbean_species_urls[caribbean].append(result['link'])


folder = "../../../data/OpenAI/Urls/"

with open(F"{folder}urls_caribbean.pkl", 'wb') as f:
    pickle.dump(caribbean_species_urls, f)

with open(F"{folder}google_urls_caribbean.pkl", 'wb') as f:
    pickle.dump(caribbean_species_google, f)

# %%
folder = "../../../data/OpenAI/Urls/"

with open(F"{folder}urls_caribbean.pkl", 'wb') as f:
    pickle.dump(caribbean_species_urls, f)

with open(F"{folder}google_urls_caribbean.pkl", 'wb') as f:
    pickle.dump(caribbean_species_google, f)

# %% [markdown]
# ## PlantNet

# %%
folder = "../../../data/OpenAI/Species/"

plantnet_species = pickle.load(open(F"{folder}plantnet_species.pkl", 'rb'))

try:
    folder = "../../../data/OpenAI/Urls/"
    plantnet_species_google = pickle.load(open(F"{folder}google_urls_plantnet.pkl", 'rb'))
    plantnet_species_urls = pickle.load(open(F"{folder}urls_plantnet.pkl", 'rb'))
    plantnet_done = list(plantnet_species_urls.keys())
except:
    plantnet_species_urls = collections.defaultdict(list)
    plantnet_species_google = collections.defaultdict(list)
    plantnet_done = []

# %%
plantnet_done

# %%
for plantnet in tqdm(plantnet_species):

    if plantnet in plantnet_done:
        print(plantnet, "done")
        continue

    for query in queries:
        search_query = F"{plantnet} {query}"

        # print(search_query)

        # Search results (10 per search)
        search_results = google_search(search_query, api_key=api_key, cse_id=cse_id)
        # Google Urls
        plantnet_species_google[plantnet] = search_results
        # Just the links
        for result in search_results:
            plantnet_species_urls[plantnet].append(result['link'])


folder = "../../../data/OpenAI/Urls/"

with open(F"{folder}urls_plantnet.pkl", 'wb') as f:
    pickle.dump(plantnet_species_urls, f)

with open(F"{folder}google_urls_plantnet.pkl", 'wb') as f:
    pickle.dump(plantnet_species_google, f)

# %%
folder = "../../../data/OpenAI/Urls/"

with open(F"{folder}urls_plantnet.pkl", 'wb') as f:
    pickle.dump(plantnet_species_urls, f)

with open(F"{folder}google_urls_plantnet.pkl", 'wb') as f:
    pickle.dump(plantnet_species_google, f)
